# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('df_clean.csv')

# %%
df.head(5)
# Out:
#   album_type  track_duration  nombre_artist track_release_month  danceability  \
# 0      album           30000              1            December        0.3210
# 1      album           30000              1             January        0.2750
# 2      album           30000              1               March        0.1760
# 3      album           30000              1            December        0.0837
# 4      album           30000              1            December        0.2140
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.952  6.0   -16.922   1.0       0.2100        0.7050             0.978
# 1   0.912  3.0   -23.424   1.0       0.0704        0.9670             0.916
# 2   0.999  2.0   -25.388   1.0       0.0786        0.0677             0.662
# 3   0.208  7.0   -20.947   1.0       0.0422        0.7000             0.880
# 4   0.236  7.0   -20.772   1.0       0.0448        0.6780             0.878
#
#    liveness  valence    tempo  time_signature pays_du_producteur  popularity
# 0    0.3400  0.03230  101.659             4.0                 AU         0.0
# 1    0.1990  0.00000   37.771             4.0                 us        35.0
# 2    0.7620  0.00001   98.109             4.0                 ZZ        59.0
# 3    0.0606  0.06500  168.334             5.0                 GB        35.0
# 4    0.0637  0.03920   79.725             4.0                 GB        38.0

# %%
sns.histplot(data=df, y="album_type")
# Out:
# <Axes: xlabel='Count', ylabel='album_type'>

# %%
for col in df.columns:
    print(col)
    sns.histplot(data=df, y=col)

# %%
num_cols = df._get_numeric_data().columns
cols = df.columns
cat_cols = list(set(cols) - set(num_cols))
cat_cols
# Out:
# ['album_type', 'track_release_month', 'pays_du_producteur']

# %%
for col in num_cols :
    # sns.histplot(df[col])
    # plt.show()
    sns.distplot(df[col], kde=False, hist_kws={'log': True})
    plt.show()
# Out:
# /var/folders/cq/rtjptvh55mx98pdv787t928w0000gp/T/ipykernel_75631/2716742860.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], kde=False, hist_kws={'log': True})
# /Users/leonzhang/Desktop/Projet-r-capitulatif---Machine-Learning/env/lib/python3.9/site-packages/seaborn/distributions.py:2502: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.hist(a, bins, orientation=orientation,

# %%
sns.heatmap(df.corr()) 
plt.show()
# Out:
# /var/folders/cq/rtjptvh55mx98pdv787t928w0000gp/T/ipykernel_75631/4097174042.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
