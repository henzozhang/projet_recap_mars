# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 200

# %%
df=pd.read_csv('df_projet_recapitulatif_200.csv')

# %%
df.isnull().sum()
# Out:
# track_id                  0
# album_type                0
# track_name                4
# track_duration            0
# track_release_date        0
# nombre_artist             0
# track_release_month       0
# danceability           2412
# energy                 2412
# key                    2412
# loudness               2412
# mode                   2412
# speechiness            2412
# acousticness           2412
# instrumentalness       2412
# liveness               2412
# valence                2412
# tempo                  2412
# time_signature         2412
# pays_du_producteur       31
# popularity               31
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#                       track_id album_type                        track_name  \
# 0       1qXyWa9GwE0jTStho20sVm     single             Tiempo es la Cuestión
# 1       5MNiJgpE50xnaSpiOhT0Bx      album  Aggressive Perfector - Live 1984
# 2       7yxyqjHv8lADQNymfHthO7      album       Face The Slayer - Live 1984
# 3       0lvx16C72kzlRikqWPZHC4      album     The Final Command - Live 1984
# 4       0JOSG1yPkLVDQQM5CsWvcN      album         Captor Of Sin - Live 1984
# ...                        ...        ...                               ...
# 230841  0jTrIZAlh1wfpKo74k0qYo      album                           Ekstase
# 230842  7rLoA0s74HQzeKKHnN3s6p      album                           Nattmat
# 230843  13ffWYhKttKJFcdpZ0OdPI      album                    Min Sista Pils
# 230844  0QFGZqqB1KDpOtyL3vXMXo     single                           Believe
# 230845  4FgMhWEpAQp7HlGUmwNglj     single                Primer Amor - Live
#
# ...

# %%
df.describe()
# Out:
#        track_duration  nombre_artist   danceability         energy  \
# count    2.284030e+05  228403.000000  228403.000000  228403.000000
# mean     2.032859e+05       1.760958       0.612663       0.588896
# std      1.037209e+05       2.235127       0.183237       0.235483
# min      1.165000e+04       1.000000       0.053300       0.000020
# 25%      1.575015e+05       1.000000       0.509000       0.440000
# 50%      1.909380e+05       1.000000       0.644000       0.619000
# 75%      2.310540e+05       2.000000       0.746000       0.771000
# max      4.437978e+06      92.000000       0.991000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  228403.000000  228403.000000  228403.000000  228403.000000
# mean        5.268714      -9.456172       0.587304       0.139667
# std         3.612869       6.234958       0.492320       0.190555
# min         0.000000     -54.196000       0.000000       0.022100
# ...

# %%
df = df.sort_values('track_duration', ascending=True)
df.head(50)
# Out:
#                       track_id   album_type  \
# 37499   7uhuCyUgZzq2teMExWBIZk        album
# 86919   3XXMZriEgeGvFAsXkO9xHx        album
# 83050   54c0cTy509SmS2KyaIuPDz  compilation
# 173767  2zimTSa2n8gXKCbd1CzTaa  compilation
# 193977  4Kz4tkOT7R2AQ6nIJRYdyU        album
# 70095   4XA6HWnHnOSErInJBTBS4J        album
# 90923   4PjInh93tkGJLBEHixn98F        album
# 120972  2td8gsKfvcwip5Ud4aIpgn        album
# 162067  278ndUGhxFdtZjCdnXrDRj        album
# 67262   4kmqlvBJjY770ECyzn5bkg        album
# 218883  28557PIgptB9kk83FYPIS8        album
# 177758  6pUPoMDJdAgdztaTmfaCp9        album
# 121988  0vhfAsSpb0ArhWjo9kfkoZ        album
# 222190  4XCCFcRZkpRCuoX5iz4DRV        album
# 36344   1QSKN1xLZj9mjt3c8tMRfP        album
# 7400    5qMTb5jSSYWwOOePE4B8Ex        album
# 200934  3QxOfx5po0YTRpYjQDA2Pu        album
# 190014  6NJNINYyPP5r2AWzVbbNW7  compilation
# 34414   4NQDsB3jIqEeIpJg592ukp       single
# 214854  3P9y8HSpNwSTrKcGB64wlK        album
# ...

# %%
mask= df['track_duration']>29000

# %%
df[mask].head(50)
# Out:
#                       track_id album_type  \
# 25591   3354qarmvKamR5UCay2csf      album
# 2487    69jNOhcgcjp4W8phsvV0iX      album
# 111719  0t4NE3Xsxk3JzbrXy0OLlT     single
# 128008  05ZJzZBvEbeJmzFIh4YkZZ      album
# 62071   0nhKQ5YclBD0ugBOCksS1G      album
# 114936  242wk4lPk4u7AgxiOX9KS0      album
# 214700  2jfvITwWein0qPN5gNhVH8      album
# 215534  7zdh46E9IakYxy3H8JpW3y      album
# 2308    5ycK07FqbOCZ9iN9ufijSO      album
# 542     3vJ34N7CKPYZf7YkF73xNJ      album
# 79297   31mdrxmhUC12Q8zC563EXD      album
# 41434   7tKX56LOnB7Vf4BMNCBN1A      album
# 52721   5yDu9YR7btO5m8hdhYqsHb      album
# 147314  122aZrDdSfqbqdwK6MIGH9      album
# 154197  7HPdHzzWlrFLE9I3ftePYy      album
# 125674  0BsADuIhLjoQMSfqtsYqIg      album
# 59007   0KVCg0NzBHYMjxklyBQmFf      album
# 199002  2Ws2kwpTg12si2rIgAKg8i     single
# 127948  5gSoxhaKECtFK9n5pM9sUV      album
# 59011   6CoMThU9YpwS3XmZIOFIVm      album
# 14385   2klpNXTZDt1I8SDLEa9htN      album
# ...

# %%
# Supprimer les lignes où la valeur de la colonne "duration" est inférieure à 30000
df = df.drop(df[df["track_duration"] < 30000].index)

# %%
df.describe()
# Out:
#        track_duration  nombre_artist   danceability         energy  \
# count    2.279360e+05  227936.000000  227936.000000  227936.000000
# mean     2.036551e+05       1.761547       0.612854       0.589324
# std      1.035054e+05       2.236951       0.183161       0.235282
# min      3.000000e+04       1.000000       0.053300       0.000020
# 25%      1.577665e+05       1.000000       0.510000       0.440000
# 50%      1.910485e+05       1.000000       0.644000       0.620000
# 75%      2.311420e+05       2.000000       0.746000       0.771000
# max      4.437978e+06      92.000000       0.991000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  227936.000000  227936.000000  227936.000000  227936.000000
# mean        5.268439      -9.443566       0.587226       0.139282
# std         3.612928       6.229670       0.492334       0.189917
# min         0.000000     -54.196000       0.000000       0.022100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227936 entries, 83701 to 126029
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   track_id             227936 non-null  object
#  1   album_type           227936 non-null  object
#  2   track_name           227936 non-null  object
#  3   track_duration       227936 non-null  int64
#  4   track_release_date   227936 non-null  object
#  5   nombre_artist        227936 non-null  int64
#  6   track_release_month  227936 non-null  object
#  7   danceability         227936 non-null  float64
#  8   energy               227936 non-null  float64
#  9   key                  227936 non-null  float64
#  10  loudness             227936 non-null  float64
#  11  mode                 227936 non-null  float64
#  12  speechiness          227936 non-null  float64
#  13  acousticness         227936 non-null  float64
# ...

# %%
counts =df['track_id'].value_counts()
counts
# Out:
# 7e6Tuz3Ybg1jsG9pH7Zo2u    2
# 57XZTVpMYPHt4NFitxHcPw    2
# 1OGlHuFbvRqwATu0d8pLKB    2
# 2ChVq8CrBPd0Ubxr6f2N8u    2
# 7ugo0SGLP8lPZ6WRumxO9c    2
#                          ..
# 1f32820VZo8vu4eTzdOWAo    1
# 1TGLqPDkm0wh1gJvUbgdZq    1
# 6qzNZ7lfrIB6ihBaXhZA33    1
# 3ZjZ97hJwhrBT0anA9jXak    1
# 2v3g3AeRCGKHzRqiy4uMVx    1
# Name: track_id, Length: 227852, dtype: int64

# %%
counts_dict = counts.to_dict()
counts_dict
# Out:
# {'7e6Tuz3Ybg1jsG9pH7Zo2u': 2,
#  '57XZTVpMYPHt4NFitxHcPw': 2,
#  '1OGlHuFbvRqwATu0d8pLKB': 2,
#  '2ChVq8CrBPd0Ubxr6f2N8u': 2,
#  '7ugo0SGLP8lPZ6WRumxO9c': 2,
#  '3xStWi945Bki9DVjFo94jN': 2,
#  '7aOb06LWLvKCw6EBQDwf6F': 2,
#  '5AjND9jiCjUZuFqIl2qN9f': 2,
#  '394Hc8eITpQrmlkT8h7SrP': 2,
#  '2oYGhGnrG7y44IHyjZdEEv': 2,
#  '5C5UoT5xmzgFAd9ssnHRDE': 2,
#  '08Br9XMUutlFlnP0tjnE2c': 2,
#  '4dJDp1EoH6FJIJLc2y9fbq': 2,
#  '2anLtgMnAJlyPqtTU1WKQc': 2,
#  '7o3AF3g8cxCxfaR9cufV0H': 2,
#  '7dtsG7jnVL8UjwhO9XiILo': 2,
#  '5fhs1WId4xdg6FUY9lmGhe': 2,
#  '5qz8bYf78ErEC7sTOvO3AJ': 2,
#  '6qObfl6aUDNGMnW2eBHOYJ': 2,
#  '1OYlqCoDdBFwmWCK5zKIx6': 2,
#  '5IpHcitnd0E4nmpOq4DuN3': 2,
#  '6u4rpYXG28oXORpnlVg9lh': 2,
#  '4Vy5DnMrvdhAnrdEij1N0i': 2,
#  '5xogmzhUcJoJPpqT4g7lXq': 2,
#  '6HyYdrFjUMdIcryi8fyaJm': 2,
#  '0yTlNIjHybsOgIGmgWOY8E': 2,
#  '6gwE3Sj6tluoK0bwGTOKVU': 2,
#  '5A9Ly7QvSF04m6WpuTMELv': 2,
#  '1NrbPsnL3ooFRrFWOiEljo': 2,
#  '6YQbGMhB7JIDaZKKoEJW3j': 2,
#  '3erX2xp3u0x3TFaWFpc6Ia': 2,
# ...

# %%
counts_dict = counts.to_dict()
counts_dict

liste_doublon=[]

for i in counts_dict:
    if counts_dict[i] ==2:
        liste_doublon.append(i)

# %%
len(liste_doublon)
liste_doublon
# Out:
# ['7e6Tuz3Ybg1jsG9pH7Zo2u',
#  '57XZTVpMYPHt4NFitxHcPw',
#  '1OGlHuFbvRqwATu0d8pLKB',
#  '2ChVq8CrBPd0Ubxr6f2N8u',
#  '7ugo0SGLP8lPZ6WRumxO9c',
#  '3xStWi945Bki9DVjFo94jN',
#  '7aOb06LWLvKCw6EBQDwf6F',
#  '5AjND9jiCjUZuFqIl2qN9f',
#  '394Hc8eITpQrmlkT8h7SrP',
#  '2oYGhGnrG7y44IHyjZdEEv',
#  '5C5UoT5xmzgFAd9ssnHRDE',
#  '08Br9XMUutlFlnP0tjnE2c',
#  '4dJDp1EoH6FJIJLc2y9fbq',
#  '2anLtgMnAJlyPqtTU1WKQc',
#  '7o3AF3g8cxCxfaR9cufV0H',
#  '7dtsG7jnVL8UjwhO9XiILo',
#  '5fhs1WId4xdg6FUY9lmGhe',
#  '5qz8bYf78ErEC7sTOvO3AJ',
#  '6qObfl6aUDNGMnW2eBHOYJ',
#  '1OYlqCoDdBFwmWCK5zKIx6',
#  '5IpHcitnd0E4nmpOq4DuN3',
#  '6u4rpYXG28oXORpnlVg9lh',
#  '4Vy5DnMrvdhAnrdEij1N0i',
#  '5xogmzhUcJoJPpqT4g7lXq',
#  '6HyYdrFjUMdIcryi8fyaJm',
#  '0yTlNIjHybsOgIGmgWOY8E',
#  '6gwE3Sj6tluoK0bwGTOKVU',
#  '5A9Ly7QvSF04m6WpuTMELv',
#  '1NrbPsnL3ooFRrFWOiEljo',
#  '6YQbGMhB7JIDaZKKoEJW3j',
#  '3erX2xp3u0x3TFaWFpc6Ia',
#  '7jyie1P4plckWBwpNc4sLz',
#  '6O7eO7M1yjPm5UmpStaFAQ',
#  '0QbejtheJHt5y1KfTIiVfD',
# ...

# %%
for i in liste_doublon:
    mask = df['track_id'] == i
    liste_index = df[mask].index
    liste_index= liste_index.tolist()
    df.drop(liste_index[0], inplace=True)

# %%
df['track_id'].value_counts()
# Out:
# 0F8KUkSq3S9HO5JpzZg8tY    1
# 3kUlDjJde0qkFchCp9a8mh    1
# 1wcvCfsecvgLeRew5cX4z0    1
# 0E9F1CMVpgrV6Vgrjwiibo    1
# 4jxZbFyulW60usvOj6XMmb    1
#                          ..
# 3hAAeeqdDFbHK1uULFtNw2    1
# 1xux4PzX7KOwNFVRnnfpSe    1
# 6LjIbCKmcH0WaK3Eg6wjj8    1
# 156v7eKUNNRwpeFaJyHbWn    1
# 2v3g3AeRCGKHzRqiy4uMVx    1
# Name: track_id, Length: 227852, dtype: int64

# %%
# df.to_csv('df_clean_projet_recapitulatif.csv',index=False)
df=pd.read_csv('df_clean_projet_recapitulatif.csv')

# %%
df['track_id'].value_counts()
# Out:
# 0F8KUkSq3S9HO5JpzZg8tY    1
# 5L68xc1ER8qHwxRZ8EDffm    1
# 35W6tr9rXbyWbKAcLo6vnG    1
# 1wcvCfsecvgLeRew5cX4z0    1
# 0E9F1CMVpgrV6Vgrjwiibo    1
#                          ..
# 3hAAeeqdDFbHK1uULFtNw2    1
# 1xux4PzX7KOwNFVRnnfpSe    1
# 6LjIbCKmcH0WaK3Eg6wjj8    1
# 156v7eKUNNRwpeFaJyHbWn    1
# 2v3g3AeRCGKHzRqiy4uMVx    1
# Name: track_id, Length: 227851, dtype: int64

# %%
df.isnull().sum()
# Out:
# track_id               0
# album_type             0
# track_name             0
# track_duration         0
# track_release_date     0
# nombre_artist          0
# track_release_month    0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# time_signature         0
# pays_du_producteur     0
# popularity             0
# dtype: int64

# %%
df
# Out:
#                       track_id album_type  \
# 0       0F8KUkSq3S9HO5JpzZg8tY      album
# 1       177ApxuQPpV8nq9zmfI71W      album
# 2       64K3dHsIU3a9fwkgwfWJoU      album
# 3       4aaIRMimoUhD1X7Ch4kYHV      album
# 4       20M8M0ifvVoPRwfhlGjO8v      album
# ...                        ...        ...
# 227846  3zpKanHYlJ91FnrW3KSWi2     single
# 227847  5Nl6uGTSTTiKIGg7KCfLTB     single
# 227848  1w9k2mjACIoa6lJ589TYnb      album
# 227849  0EmBd60hmUVkgM33ugM6PK      album
# 227850  2v3g3AeRCGKHzRqiy4uMVx      album
#
#                                        track_name  track_duration  \
# 0       Squeaking Dolphins and Calming Piano Pt 3           30000
# 1             Soothing White Noise Piano Melodies           30000
# 2                   Rain and Thunderstorm, Pt. 28           30000
# 3                                   Warrior Intro           30000
# 4                                   Warrior Intro           30000
# ...

# %%
from langdetect import detect

title = " Squeaking Dolphins and Calming Piano Pt 3 "
language = detect(title)

print(language)
# Out:
# tl

# %%
def find_language(text):
    language = detect(text)
    return language

# %%
df12=df.head(50)

# %%
try :
    df12['language_title']=df12['track_name'].apply(find_language)
except:
    pass
# Out:
# /var/folders/cq/rtjptvh55mx98pdv787t928w0000gp/T/ipykernel_33986/3671765006.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['language_title']=df12['track_name'].apply(find_language)

# %%
df12.head(5)
# Out:
#                  track_id album_type  \
# 0  0F8KUkSq3S9HO5JpzZg8tY      album
# 1  177ApxuQPpV8nq9zmfI71W      album
# 2  64K3dHsIU3a9fwkgwfWJoU      album
# 3  4aaIRMimoUhD1X7Ch4kYHV      album
# 4  20M8M0ifvVoPRwfhlGjO8v      album
#
#                                   track_name  track_duration  \
# 0  Squeaking Dolphins and Calming Piano Pt 3           30000
# 1        Soothing White Noise Piano Melodies           30000
# 2              Rain and Thunderstorm, Pt. 28           30000
# 3                              Warrior Intro           30000
# 4                              Warrior Intro           30000
#
#   track_release_date  nombre_artist track_release_month  danceability  energy  \
# 0         2022-12-30              1            December        0.3210   0.952
# 1         2022-01-06              1             January        0.2750   0.912
# 2         2022-03-14              1               March        0.1760   0.999
# ...

# %%
df =df.drop(['track_release_date','track_id','track_name'],axis=1)
df
# Out:
#        album_type  track_duration  nombre_artist track_release_month  \
# 0           album           30000              1            December
# 1           album           30000              1             January
# 2           album           30000              1               March
# 3           album           30000              1            December
# 4           album           30000              1            December
# ...           ...             ...            ...                 ...
# 227846     single         3942187              1            December
# 227847     single         3957655              1             October
# 227848      album         4021422              1             January
# 227849      album         4424757              1                July
# 227850      album         4437978              1                July
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df
# Out:
#        album_type  track_duration  nombre_artist track_release_month  \
# 0           album           30000              1            December
# 1           album           30000              1             January
# 2           album           30000              1               March
# 3           album           30000              1            December
# 4           album           30000              1            December
# ...           ...             ...            ...                 ...
# 227846     single         3942187              1            December
# 227847     single         3957655              1             October
# 227848      album         4021422              1             January
# 227849      album         4424757              1                July
# 227850      album         4437978              1                July
#
#         danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227851 entries, 0 to 227850
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   album_type           227851 non-null  object
#  1   track_duration       227851 non-null  int64
#  2   nombre_artist        227851 non-null  int64
#  3   track_release_month  227851 non-null  object
#  4   danceability         227851 non-null  float64
#  5   energy               227851 non-null  float64
#  6   key                  227851 non-null  float64
#  7   loudness             227851 non-null  float64
#  8   mode                 227851 non-null  float64
#  9   speechiness          227851 non-null  float64
#  10  acousticness         227851 non-null  float64
#  11  instrumentalness     227851 non-null  float64
#  12  liveness             227851 non-null  float64
#  13  valence              227851 non-null  float64
# ...

# %%
df['pays_du_producteur'] = df['pays_du_producteur'].str.upper()

# %%
keep_pays = df['pays_du_producteur'].value_counts()

# %%
keep_pays =keep_pays.to_dict()

# %%
liste_to_drop =[]
for pays in keep_pays:
    if keep_pays[pays]<200:
        liste_to_drop.append(pays)

# %%
df = df[~df['pays_du_producteur'].isin(liste_to_drop)]

# %%
df['pays_du_producteur'].value_counts()
# Out:
# US    37499
# QZ    30231
# DE    17906
# GB    15178
# FR    15017
# QM     8103
# IN     6261
# SE     4868
# JP     4728
# IT     4651
# NL     4270
# TC     4198
# ES     3953
# BR     3696
# ZA     3506
# KR     3485
# GR     2744
# PL     2731
# CZ     2535
# GX     2532
# DG     2440
# MX     2248
# AR     2195
# CH     2091
# DK     2044
# HK     2041
# BC     2031
# RU     1964
# BX     1803
# AU     1795
# UK     1696
# CA     1659
# TR     1650
# TW     1545
# ZZ     1484
# FI     1402
# IL     1232
# RS     1171
# NO     1097
# KS     1094
# VN      937
# AT      779
# RO      748
# MY      719
# AE      706
# TH      694
# BE      669
# LB      595
# HU      588
# PH      583
# ID      575
# PT      569
# EG      556
# UY      499
# SK      482
# HR      435
# CO      379
# BG      350
# ZB      342
# IS      341
# SG      304
# CL      290
# BK      271
# UA      246
# BA      225
# CN      209
# Name: pays_du_producteur, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225865 entries, 0 to 227850
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   album_type           225865 non-null  object
#  1   track_duration       225865 non-null  int64
#  2   nombre_artist        225865 non-null  int64
#  3   track_release_month  225865 non-null  object
#  4   danceability         225865 non-null  float64
#  5   energy               225865 non-null  float64
#  6   key                  225865 non-null  float64
#  7   loudness             225865 non-null  float64
#  8   mode                 225865 non-null  float64
#  9   speechiness          225865 non-null  float64
#  10  acousticness         225865 non-null  float64
#  11  instrumentalness     225865 non-null  float64
#  12  liveness             225865 non-null  float64
#  13  valence              225865 non-null  float64
# ...

# %%
df.to_csv('df_clean.csv',index=False)
