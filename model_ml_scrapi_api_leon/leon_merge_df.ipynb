# %%
import pandas as pd

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 200

# %%
df=pd.read_csv('spotify_api_search/tracks_2022.csv')
df.head(5)
# Out:
#                  track_id album_type                        track_name  \
# 0  1qXyWa9GwE0jTStho20sVm     single             Tiempo es la Cuestión
# 1  5MNiJgpE50xnaSpiOhT0Bx      album  Aggressive Perfector - Live 1984
# 2  7yxyqjHv8lADQNymfHthO7      album       Face The Slayer - Live 1984
# 3  0lvx16C72kzlRikqWPZHC4      album     The Final Command - Live 1984
# 4  0JOSG1yPkLVDQQM5CsWvcN      album         Captor Of Sin - Live 1984
#
#    track_duration track_release_date  nombre_artist
# 0          190027         2022-10-22              2
# 1          135325         2022-10-18              1
# 2          227031         2022-10-18              1
# 3          151560         2022-10-18              1
# 4          205896         2022-10-18              1

# %%
len(df)
# Out:
# 230762

# %%
df['track_release_month'] = pd.to_datetime(df['track_release_date']).dt.strftime('%B')

# %%
df
# Out:
#                       track_id album_type                        track_name  \
# 0       1qXyWa9GwE0jTStho20sVm     single             Tiempo es la Cuestión
# 1       5MNiJgpE50xnaSpiOhT0Bx      album  Aggressive Perfector - Live 1984
# 2       7yxyqjHv8lADQNymfHthO7      album       Face The Slayer - Live 1984
# 3       0lvx16C72kzlRikqWPZHC4      album     The Final Command - Live 1984
# 4       0JOSG1yPkLVDQQM5CsWvcN      album         Captor Of Sin - Live 1984
# ...                        ...        ...                               ...
# 230757  0jTrIZAlh1wfpKo74k0qYo      album                           Ekstase
# 230758  7rLoA0s74HQzeKKHnN3s6p      album                           Nattmat
# 230759  13ffWYhKttKJFcdpZ0OdPI      album                    Min Sista Pils
# 230760  0QFGZqqB1KDpOtyL3vXMXo     single                           Believe
# 230761  4FgMhWEpAQp7HlGUmwNglj     single                Primer Amor - Live
#
# ...

# %%
df1=pd.read_csv('spotify_api_search/list_audio_features.csv')
df1.head(5)
# Out:
#    Unnamed: 0  danceability  energy   key  loudness  mode  speechiness  \
# 0           0         0.779   0.383   4.0   -14.817   0.0       0.0733
# 1           0         0.404   0.929   6.0   -16.160   1.0       0.0520
# 2           0         0.312   0.902   1.0   -15.262   1.0       0.0618
# 3           0         0.257   0.914  11.0   -15.322   1.0       0.1090
# 4           0         0.431   0.915   3.0   -15.925   0.0       0.0434
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0         0.794          0.000001     0.110   0.6830  103.983  audio_features
# 1         0.261          0.836000     0.446   0.0639  103.399  audio_features
# 2         0.110          0.231000     0.380   0.1180   97.277  audio_features
# 3         0.412          0.403000     0.135   0.2540  107.020  audio_features
# 4         0.434          0.765000     0.459   0.0579  110.864  audio_features
#
#                        id                                   uri  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df1['track_id']=df1['id']

# %%
list_to_keep = ['track_id','danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo','time_signature']

# %%
df_audio = df1[list_to_keep]

# %%
df_merge = pd.merge(df, df_audio, on="track_id", how="left")

# %%
df_merge
# Out:
#                       track_id album_type                        track_name  \
# 0       1qXyWa9GwE0jTStho20sVm     single             Tiempo es la Cuestión
# 1       5MNiJgpE50xnaSpiOhT0Bx      album  Aggressive Perfector - Live 1984
# 2       7yxyqjHv8lADQNymfHthO7      album       Face The Slayer - Live 1984
# 3       0lvx16C72kzlRikqWPZHC4      album     The Final Command - Live 1984
# 4       0JOSG1yPkLVDQQM5CsWvcN      album         Captor Of Sin - Live 1984
# ...                        ...        ...                               ...
# 230841  0jTrIZAlh1wfpKo74k0qYo      album                           Ekstase
# 230842  7rLoA0s74HQzeKKHnN3s6p      album                           Nattmat
# 230843  13ffWYhKttKJFcdpZ0OdPI      album                    Min Sista Pils
# 230844  0QFGZqqB1KDpOtyL3vXMXo     single                           Believe
# 230845  4FgMhWEpAQp7HlGUmwNglj     single                Primer Amor - Live
#
# ...

# %%
df_popu=pd.read_csv('spotify_api_search/several_tracks_popularity.csv')
df_popu.head(5)
df_popu=df_popu[['track_id','pays_du_producteur','popularity']]
df_popu
# Out:
#                       track_id pays_du_producteur  popularity
# 0       1qXyWa9GwE0jTStho20sVm                 SE          22
# 1       5MNiJgpE50xnaSpiOhT0Bx                 GX          21
# 2       7yxyqjHv8lADQNymfHthO7                 GX          19
# 3       0lvx16C72kzlRikqWPZHC4                 GX          19
# 4       0JOSG1yPkLVDQQM5CsWvcN                 GX          16
# ...                        ...                ...         ...
# 230726  0jTrIZAlh1wfpKo74k0qYo                 QM          15
# 230727  7rLoA0s74HQzeKKHnN3s6p                 QM          16
# 230728  13ffWYhKttKJFcdpZ0OdPI                 QM          19
# 230729  0QFGZqqB1KDpOtyL3vXMXo                 US          55
# 230730  4FgMhWEpAQp7HlGUmwNglj                 QZ          32
#
# [230731 rows x 3 columns]

# %%
df_merge1 = pd.merge(df_merge, df_popu, on="track_id", how="left")

# %%
df_merge1['track_id'].value_counts()
# Out:
# 2oYGhGnrG7y44IHyjZdEEv    2
# 1tGqhouSg5HWH9bMorRwjO    2
# 3diNU8pBLw0B2BBi3iFLxP    2
# 3sfrlhn6qucEcJFoOxCFQD    2
# 26t6CecBxVaxQLttuvIJJt    2
#                          ..
# 4EDth8B1BvrKX3nR429rAn    1
# 7BuG50amxx1PSSZ2OfECB4    1
# 07wk5ucNmqDDt6qMiUTXKW    1
# 5ZsShHjVhvRyeEizgoqK1P    1
# 4FgMhWEpAQp7HlGUmwNglj    1
# Name: track_id, Length: 230762, dtype: int64

# %%
df= df_merge1

# %%
mask=df['track_id']=='2oYGhGnrG7y44IHyjZdEEv'
df
# Out:
#                       track_id album_type                        track_name  \
# 0       1qXyWa9GwE0jTStho20sVm     single             Tiempo es la Cuestión
# 1       5MNiJgpE50xnaSpiOhT0Bx      album  Aggressive Perfector - Live 1984
# 2       7yxyqjHv8lADQNymfHthO7      album       Face The Slayer - Live 1984
# 3       0lvx16C72kzlRikqWPZHC4      album     The Final Command - Live 1984
# 4       0JOSG1yPkLVDQQM5CsWvcN      album         Captor Of Sin - Live 1984
# ...                        ...        ...                               ...
# 230841  0jTrIZAlh1wfpKo74k0qYo      album                           Ekstase
# 230842  7rLoA0s74HQzeKKHnN3s6p      album                           Nattmat
# 230843  13ffWYhKttKJFcdpZ0OdPI      album                    Min Sista Pils
# 230844  0QFGZqqB1KDpOtyL3vXMXo     single                           Believe
# 230845  4FgMhWEpAQp7HlGUmwNglj     single                Primer Amor - Live
#
# ...
