# %%
import pandas as pd
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
import time

# %% [markdown]
# ## methode audio_features

# %%
client_id = 'b24dae7b869c458fb3a35e44bdc6a564'
client_secret = '57188e42ffe542bfb61335bb4aaceba7'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
liste_track=['0fkLAVPtJP4f3fPF3PM2Ph','0kVlxAK16JbhTb5Idu9aqB']
audio_features = sp.audio_features(liste_track)
pprint.pprint(audio_features)
# Out:
# [{'acousticness': 0.676,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fkLAVPtJP4f3fPF3PM2Ph',
#   'danceability': 0.502,
#   'duration_ms': 296477,
#   'energy': 0.505,
#   'id': '0fkLAVPtJP4f3fPF3PM2Ph',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.146,
#   'loudness': -4.559,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'tempo': 129.715,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0fkLAVPtJP4f3fPF3PM2Ph',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0fkLAVPtJP4f3fPF3PM2Ph',
#   'valence': 0.316},
#  {'acousticness': 0.0335,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0kVlxAK16JbhTb5Idu9aqB',
#   'danceability': 0.726,
#   'duration_ms': 200777,
#   'energy': 0.596,
#   'id': '0kVlxAK16JbhTb5Idu9aqB',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.143,
#   'loudness': -6.626,
#   'mode': 1,
#   'speechiness': 0.261,
#   'tempo': 155.087,
#   'time_signature': 4,
# ...

# %%
def find_audio_feature(audio_features):
    
    time.sleep(0.3)

    df = pd.DataFrame(columns=['track_id', 'acousticness', 'danceability','duration_ms', 'energy', 'instrumentalness','key', 'liveness', 'loudness','mode', 'speechiness', 'tempo','time_signature', 'valence'])
    for audio_feature in audio_features:
            
            track_id = audio_feature['id']
            acousticness = audio_feature['acousticness']
            danceability = audio_feature['danceability']
            duration_ms = audio_feature['duration_ms']
            energy = audio_feature['energy']
            instrumentalness = audio_feature['instrumentalness']
            key = audio_feature['key']
            liveness = audio_feature['liveness']
            loudness = audio_feature['loudness']
            mode = audio_feature['mode']
            speechiness = audio_feature['speechiness']
            tempo = audio_feature['tempo']
            time_signature = audio_feature['time_signature']
            valence = audio_feature['valence']
         
            new_row = {'track_id':track_id ,
                       'acousticness': acousticness,
                        'danceability':danceability ,
                        'duration_ms':duration_ms ,
                        'energy': energy,
                        'instrumentalness': instrumentalness,
                        'key': key,
                        'liveness': liveness,
                        'loudness': loudness,
                        'mode': mode,
                        'speechiness':speechiness,
                        'tempo': tempo,
                        'time_signature': time_signature,
                        'valence':valence }
            df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    return df


def division_liste(liste_a_diviser,nombre_element):

    sous_listes = []
    sous_liste_temporaire = []

    for element in liste_a_diviser:
        sous_liste_temporaire.append(element)
        
        if len(sous_liste_temporaire) == nombre_element:
            sous_listes.append(sous_liste_temporaire)
            sous_liste_temporaire = []
            
    if len(sous_liste_temporaire) > 0:
        sous_listes.append(sous_liste_temporaire)

    return sous_listes

# %%
df =find_audio_feature(audio_features)
df
# Out:
#                  track_id  acousticness  danceability duration_ms  energy  \
# 0  0fkLAVPtJP4f3fPF3PM2Ph        0.6760         0.502      296477   0.505
# 1  0kVlxAK16JbhTb5Idu9aqB        0.0335         0.726      200777   0.596
#
#   instrumentalness key  liveness  loudness mode  speechiness    tempo  \
# 0                0   7     0.146    -4.559    1       0.0303  129.715
# 1                0   8     0.143    -6.626    1       0.2610  155.087
#
#   time_signature  valence
# 0              4    0.316
# 1              4    0.236

# %%
df = pd.read_csv('list_track1.csv')
list_albums = df['track_id'].tolist()

# %%
df = pd.DataFrame(columns=['track_id', 'acousticness', 'danceability','duration_ms', 'energy', 'instrumentalness','key', 'liveness', 'loudness','mode', 'speechiness', 'tempo','time_signature', 'valence'])

df = pd.read_csv('')

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


df = pd.DataFrame(columns=['track_id', 'acousticness', 'danceability','duration_ms', 'energy', 'instrumentalness','key', 'liveness', 'loudness','mode', 'speechiness', 'tempo','time_signature', 'valence'])
cd=0
for i in range(4000,5000):
    audio_features = sp.audio_features(liste_albums_divise[i])
    df1=find_audio_feature(audio_features)
    df = pd.concat([df, df1])
    print(cd)
    cd+=1

df.to_csv('audio_features.csv', index=False)

# %%
#version colab

path = '/content/drive/MyDrive/data/list_audio_features.csv'
df_track = pd.read_csv(path)

cd=0
for i in range(2308):

  audio_features = sp.audio_features(list_track_2022_divise[i])
  for audio_featur in audio_features:
    df1 = pd.DataFrame(audio_featur,index=[0])
    df = pd.concat([df, df1])
  print(cd)
  cd+=1

path = '/content/drive/MyDrive/data/list_audio_features.csv'

df.to_csv(path)
# df.to_csv('audio_features.csv', index=False)

# %% [markdown]
# ## methode several_tracks

# %%
client_id = '83da47edd13b43079be550120ab93196'
client_secret = 'dc97c1598eb24da0a48abd7a3718c375'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
list_track_2022_divise=['7FHmZ3gosfYXqYcedXG1jd']
several_tracks = sp.tracks(list_track_2022_divise)
pprint.pprint(several_tracks)
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HIMUuiAPvtlEOsDdlyHsD'},
#                                     'href': 'https://api.spotify.com/v1/artists/1HIMUuiAPvtlEOsDdlyHsD',
#                                     'id': '1HIMUuiAPvtlEOsDdlyHsD',
#                                     'name': 'Tanjib Sarowar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1HIMUuiAPvtlEOsDdlyHsD'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
# ...

# %%
df = pd.DataFrame(columns=['track_id', 'pays_du_producteur', 'popularity'])

# %%
for several_track in several_tracks['tracks']:
  track_id = several_track['id']
  pays_du_producteur=several_track['external_ids']['isrc'][:2]
  popularity = several_track['popularity']
  new_row = {'track_id':track_id ,
              'pays_du_producteur': pays_du_producteur,
              'popularity':popularity }
  df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
  # print(several_track)
  # print(len(several_track))
df
# Out:
#                  track_id pays_du_producteur popularity
# 0  0fkLAVPtJP4f3fPF3PM2Ph       KRA381901476         34
# 1  0kVlxAK16JbhTb5Idu9aqB       QZFYY2205392          0
# 2  0fkLAVPtJP4f3fPF3PM2Ph                 KR         34
# 3  0kVlxAK16JbhTb5Idu9aqB                 QZ          0
